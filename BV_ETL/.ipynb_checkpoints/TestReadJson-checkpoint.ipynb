# %%
import pandas as pd
import json
import requests
import os
import pprint

# %%
# import us-states data
filepath = os.path.join("data", "output", "obesity_states_clean.json")
with open(filepath) as jsonfile:
    data = json.load(jsonfile)

# %%
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "adults_obese_percent": {
#         "Alabama": 36.3,
#         "Alaska": 34.2,
#         "Arizona": 29.5,
#         "Arkansas": 35.0,
#         "California": 25.1,
#         "Colorado": 22.6,
#         "Connecticut": 26.9,
#         "Delaware": 31.8,
#         "Florida": 28.4,
#         "Georgia": 31.6,
#         "Hawaii": 23.8,
#         "Idaho": 29.3,
#         "Illinois": 31.1,
#         "Indiana": 33.6,
#         "Iowa": 36.4,
#         "Kansas": 32.4,
#         "Kentucky": 34.3,
#         "Louisiana": 36.2,
#         "Maine": 29.1,
#         "Maryland": 31.3,
#         "Massachusetts": 25.9,
#         "Michigan": 32.3,
#         "Minnesota": 28.4,
#         "Mississippi": 37.3,
#         "Missouri": 32.5,
#         "Montana": 25.3,
#         "Nebraska": 32.8,
#         "Nevada": 26.7,
#         "New Hampshire": 28.1,
#         "New Jersey": 27.3,
#         "New Mexico": 28.4,
#         "New York": 25.7,
#         "North Carolina": 32.1,
#         "North Dakota": 33.2,
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#                                                            coords  \
# Alabama         [[[-87.359296, 35.00118], [-85.606675, 34.9847...
# Alaska          [[[-87.359296, 35.00118], [-85.606675, 34.9847...
# Arizona         [[[-87.359296, 35.00118], [-85.606675, 34.9847...
# Arkansas        [[[-87.359296, 35.00118], [-85.606675, 34.9847...
# California      [[[-87.359296, 35.00118], [-85.606675, 34.9847...
# Colorado        [[[-87.359296, 35.00118], [-85.606675, 34.9847...
# Connecticut     [[[-87.359296, 35.00118], [-85.606675, 34.9847...
# Delaware        [[[-87.359296, 35.00118], [-85.606675, 34.9847...
# Florida         [[[-87.359296, 35.00118], [-85.606675, 34.9847...
# Georgia         [[[-87.359296, 35.00118], [-85.606675, 34.9847...
# Hawaii          [[[-87.359296, 35.00118], [-85.606675, 34.9847...
# Idaho           [[[-87.359296, 35.00118], [-85.606675, 34.9847...
# Illinois        [[[-87.359296, 35.00118], [-85.606675, 34.9847...
# ...
